# %%
#implementing dimensionality reduction 
#we have to reduce dimension from 100D to 2D
#because we cannot visualize 100D
#this let us visually see:
#Similar words cluster together
#opposite words seperate 
#sematic relationships

# %%
#we can reduce the dimensios byusing 
#PCA-linear reduction
#t-SNE-NON linear
# UMAP

# %%
# First, install the missing package
# !pip install gensim

# Then import the modules
import gensim.downloader as api
import matplotlib.pyplot as plt 
from sklearn.decomposition import PCA
# Out:
# Requirement already satisfied: gensim in c:\users\atul\anaconda3\lib\site-packages (4.4.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\atul\anaconda3\lib\site-packages (from gensim) (2.1.3)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\atul\anaconda3\lib\site-packages (from gensim) (1.15.3)
# Requirement already satisfied: smart_open>=1.8.1 in c:\users\atul\anaconda3\lib\site-packages (from gensim) (7.5.0)
# Requirement already satisfied: wrapt in c:\users\atul\anaconda3\lib\site-packages (from smart_open>=1.8.1->gensim) (1.17.0)

# %%
model=api.load("glove-wiki-gigaword-100")
print("model successfull")
# Out:
# model successfull

# %%
words=[
    "king","queen","man","woman",
    "dog","cat","animal",
    "car","truck","vehicle",
    "happy","sad","joy","anger"
]
vectors=[model[word]for word in words]

# %%
pca = PCA(n_components=2)
reduced = pca.fit_transform(vectors)

# %%
plt.figure(figsize=(10,6))
for i,word in enumerate(words):
    x=reduced[i][0]
    y=reduced[i][1]
    plt.scatter(x,y)
    plt.text(x+0.01,y+0.01,word)
plt.title("word embedding pca")
plt.show()

# %%
from sklearn.manifold import TSNE

# %%
import numpy as np
from sklearn.manifold import TSNE

vectors_array = np.array(vectors)

tsne = TSNE(n_components=2,perplexity=3)
reduced = tsne.fit_transform(vectors_array)

# %%
plt.figure(figsize=(10,6))
for i,word in enumerate(words):
    x=reduced[i][0]
    y=reduced[i][1]
    plt.scatter(x,y)
    plt.text(x+0.01,y+0.01,word)
plt.title("word embedding pca")
plt.show()
