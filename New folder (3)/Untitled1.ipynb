# %%
# First, install the missing package
# !pip install yt-dlp

# Then import the modules
import cv2
import yt_dlp

# Now you can use these modules in your code
# Out:
# Collecting yt-dlp
#   Downloading yt_dlp-2026.3.17-py3-none-any.whl.metadata (182 kB)
# Downloading yt_dlp-2026.3.17-py3-none-any.whl (3.3 MB)
#    ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#    ------------------------- -------------- 2.1/3.3 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------------- 3.3/3.3 MB 14.4 MB/s eta 0:00:00
# Installing collected packages: yt-dlp
# Successfully installed yt-dlp-2026.3.17

# %%
URL="https://www.youtube.com/watch?v=DKzBmRRdPXo"
ydl_options={
    'format':'best[ext=mp4]'
}
with yt_dlp.YoutubeDL(ydl_options) as ydl:
    info=ydl.extract_info(URL,download=False)
    #Get video stream URL
    video_url= info['url']
    cap=cv2.VideoCapture(video_url)
    while True:
        #get frames from video
        ret, frame=cap.read()
        #break if video ends or fails
        if not ret:
            break
        cv2.imshow("My camera",frame)
        key=cv2.waitKey(25) & 0xFF  #milliseconds
        if key==27: #27: ESC
            break 
    cap.release()
    cv2.destroyAllWindows()
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=DKzBmRRdPXo
# [youtube] DKzBmRRdPXo: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] DKzBmRRdPXo: Downloading android vr player API JSON
