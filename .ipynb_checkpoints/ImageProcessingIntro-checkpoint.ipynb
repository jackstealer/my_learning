# %%
#!pip install opencv-python
#cv2- Computer Vision
# %pip install opencv-python
#%pip install matplotlib
#!pip install opencv-python
import cv2

# %%
img=cv2.imread("msd1.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
#271:height, 186:width, rgb:3, greyscale:2
# Out:
# (632, 474, 3)

# %%
img[0]
# Out:
# array([[75, 63, 15],
#        [75, 63, 15],
#        [75, 63, 15],
#        ...,
#        [78, 68, 20],
#        [80, 70, 22],
#        [80, 70, 22]], shape=(474, 3), dtype=uint8)

# %%
import matplotlib.pyplot as plt 
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
#plt.show()

# %%
cv2.imshow("MSD",img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
#while
#Loop to check key press
while True:
    key=cv2.waitKey(0) & 0xFF
    #ESC key(27) is more reliable than 'q'
    if key==27:
        break

cv2.destroyAllWindows()
