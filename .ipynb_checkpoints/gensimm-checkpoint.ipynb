# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in C:\Program Files\Python313\Lib\site-packages (4.4.0)
# Requirement already satisfied: numpy>=1.18.5 in C:\Program Files\Python313\Lib\site-packages (from gensim) (2.3.5)
# Requirement already satisfied: scipy>=1.7.0 in C:\Program Files\Python313\Lib\site-packages (from gensim) (1.17.0)
# Requirement already satisfied: smart_open>=1.8.1 in C:\Program Files\Python313\Lib\site-packages (from gensim) (7.5.0)
# Requirement already satisfied: wrapt in C:\Program Files\Python313\Lib\site-packages (from smart_open>=1.8.1->gensim) (2.1.1)

# %%
import gensim.downloader as api
import numpy as np
from nltk.tokenize import word_tokenize
import nltk
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
print("Loading model....")
model = api.load("glove-wiki-gigaword-100")
print("Loaded")
# Out:
# Loading model....
# Loaded

# %%
sentence = "Please open google and check weather"
tokens = word_tokenize(sentence.lower())

# %%
# Sliding window function
def get_windows(tokens, window_size=2):
  windows=[]
  for i in range(len(tokens)):
    left = max(0,i-window_size)
    right = min(len(tokens),i+window_size+1)
    window_words= tokens[left:right]
    windows.append(window_words)

  return windows

# %%
windows=get_windows(tokens,2)
print("Windows: ",windows)
# Out:
# Windows:  [['please', 'open', 'google'], ['please', 'open', 'google', 'and'], ['please', 'open', 'google', 'and', 'check'], ['open', 'google', 'and', 'check', 'weather'], ['google', 'and', 'check', 'weather'], ['and', 'check', 'weather']]

# %%
# Next step is to convert window to embedding
def window_vector(windows):
  vector= []
  for word in windows:
    if word in model:
      vector.append(model[word])

  if(len(vector)==0):
    return np.zeros(100)

  return np.mean(vector, axis=0)

# %%
windows_vector = [window_vector(w) for w in windows]

# %%
print(windows_vector[0].shape)
# Out:
# (100,)
