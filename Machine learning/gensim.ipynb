# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in C:\Program Files\Python313\Lib\site-packages (4.4.0)
# Requirement already satisfied: numpy>=1.18.5 in C:\Program Files\Python313\Lib\site-packages (from gensim) (2.3.5)
# Requirement already satisfied: scipy>=1.7.0 in C:\Program Files\Python313\Lib\site-packages (from gensim) (1.17.0)
# Requirement already satisfied: smart_open>=1.8.1 in C:\Program Files\Python313\Lib\site-packages (from gensim) (7.5.0)
# Requirement already satisfied: wrapt in C:\Program Files\Python313\Lib\site-packages (from smart_open>=1.8.1->gensim) (2.1.1)

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in C:\Program Files\Python313\Lib\site-packages (26.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize

# %%
sentences=[
    "I am learning matural language processing",
    "Natural language processing is part of machine learning",
    "I am also learning machine learning",
    "I want to learn deep learning",
    "Deep learning uses neural networks",
    "Neural networks are powerful"
]

# %%
tokenized_sentences=[word_tokenize(s.lower()) for s in sentences]
print(tokenized_sentences)
# Out:
# [['i', 'am', 'learning', 'matural', 'language', 'processing'], ['natural', 'language', 'processing', 'is', 'part', 'of', 'machine', 'learning'], ['i', 'am', 'also', 'learning', 'machine', 'learning'], ['i', 'want', 'to', 'learn', 'deep', 'learning'], ['deep', 'learning', 'uses', 'neural', 'networks'], ['neural', 'networks', 'are', 'powerful']]

# %%
model=Word2Vec(
    sentences=tokenized_sentences,
    vector_size=100, #embedding dimension - dimension of word vectors
    window=3,  #context window size - max distance b/w target and context words
    min_count=1 #keep all words - ignore words appearing less than this number
)

# %%
print(model.wv.similarity("language", "natural"))
# Out:
# 0.31899267

# %%
print(model.wv.most_similar("deep",topn=5))
# Out:
# [('to', 0.2529100179672241), ('networks', 0.1701270490884781), ('learn', 0.15016482770442963), ('machine', 0.13887980580329895), ('of', 0.1085236445069313)]

# %%
#Internally:
# During training:
# model slides window across text
# learn weighs via neural netwroks
# produces embedding matrix

#Word2Vecc is:
#a shallow neural network with one hidden layer only

#limitation of Word2vec
#Static embeddings(same vector for every context)
# "bank" - money / river

# %%
#use pretrained embeddings
# 2 popular pretrained models:
# 1. Google news Word2Vec (300 dim)
# 2. Glove (Stanford)

# %%
import gensim.downloader as api
print("Loading pretrained models:")
model = api.load("word2vec-google-news-300")
# Out:
# Loading pretrained models:

# %%
print(model.similarity("artifical","intelligence"))
print(model.most_similar("happy",topn=15))
# Out:
# 0.088428214
# [('glad', 0.7408890724182129), ('pleased', 0.6632170677185059), ('ecstatic', 0.6626912355422974), ('overjoyed', 0.6599286794662476), ('thrilled', 0.6514049172401428), ('satisfied', 0.6437949538230896), ('proud', 0.636042058467865), ('delighted', 0.627237856388092), ('disappointed', 0.6269949674606323), ('excited', 0.6247665286064148), ('happier', 0.6244627237319946), ('Said_Hirschbeck', 0.6234508752822876), ('elated', 0.6196017861366272), ('thankful', 0.6178935766220093), ('unhappy', 0.6128038167953491)]
